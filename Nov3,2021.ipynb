# %% [markdown]
# <a href="https://colab.research.google.com/github/SuryaReginaAA/Hotel-Billing/blob/main/Nov3%2C2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# functions

# %%
len
# Out:
# <function len>

# %%
type(len)
# Out:
# builtin_function_or_method

# %%
print(type(len))
# Out:
# <class 'builtin_function_or_method'>

# %%
len="im not the len function you are looking for"
print(len)
del(len)
# Out:
# im not the len function you are looking for

# %%
count=len("python")
print(count)
# Out:
# 6

# %%
def greet():
  print("Hello")
greet()
# Out:
# Hello

# %%
def greet():
  print("Hello")
greet()
greet()
greet()
greet()
greet()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
def greet(name):
  print(f"Hello {name}")
#greet()
greet("Surya")
name="Regina"
greet(name)
# Out:
# Hello Surya
# Hello Regina

# %%
def shout(string):
  string=string.upper()
  print(string)

shout("python")
word="programming"
shout(word)
print(word)
# Out:
# PYTHON
# PROGRAMMING
# programming

# %%
 def add(num1,num2):
   print(num1+num2)
  

var1=int(input("enter the variable1"))
var2=int(input("enter the variable2"))
add(var1,var2)
# Out:
# enter the variable110
# enter the variable220
# 30

# %% [markdown]
# 1.WAP to get two numbers from the user and find the product of those using function

# %%
def mul(num1,num2):
   print(f"product of {num1} and {num2} is {num1*num2}")
  

var1=int(input("enter the variable1"))
var2=int(input("enter the variable2"))
mul(var1,var2)
# Out:
# enter the variable110
# enter the variable25
# product of 10 and 5 is 50

# %% [markdown]
# 2.WAP to get the radius of a sphere and find the volume using function

# %%
def vol(radius):
  print(f" volume of the sphere is = {(4/3)*3.14*radius**3}")

r = int(input("enter the radius of the sphere"))
vol(r)
# Out:
# enter the radius of the sphere15
#  volume of the sphere is = 14130.0

# %% [markdown]
# 3.WAP to get a list from the user and implement a function to print only the even numbers which are greater than 50

# %%
def even(l):
  li=[]
  for i in l:
    if i%2==0 and i>50:
      li+=[i]
  print(li)

limit=int(input("enter the limit"))
lis=[]
for i in range(limit):
  l=int(input(f"enter the {i+1}th element : "))
  lis+=[l]
even(lis)
# Out:
# enter the limit5
# enter the 1th element : 20
# enter the 2th element : 30
# enter the 3th element : 90
# enter the 4th element : 25
# enter the 5th element : 60
# [90, 60]

# %% [markdown]
# 4.WAP to get the length and width of a rectangle and find the area and perimeter using functions and print onto screen.

# %%
1def area(l,w):
  print(f"area = {l*w} \nperimeter = {2*(l+w)}")

a=int(input("enter the length"))
b=int(input("enter the width"))
area(a,b)
# Out:
# enter the length5
# enter the width010
# area = 50
# perimeter = 30

# %% [markdown]
# 5.WAP to get a temperature reading in celcius from the user and using function, convert into farenheit scale and print onto screen.

# %%
def temp(cel):
  print(f"temperature in farenheit = {(cel * 9/5) + 32}")

t=int(input("enter the temperature in celcius"))
temp(t)
# Out:
# enter the temperature in celcius25
# temperature in farenheit = 77.0

# %% [markdown]
# 6.WAP to get a number from the user and using function, find the factorial of that number and print onto the screen.

# %%
def fact(n):
  if(n<=0):
    return 1
  else:
    return n*fact(n-1)
#print("factorial =",fact)
num=int(input("enter number"))
print(fact(num))
# Out:
# enter number5
# 120

# %%
def fact(n):
  f=1
  for i in range(1,n+1):
    f=f*i
  print(f)

num=int(input("enter number"))
fact(num)
# Out:
# enter number5
# 120

# %% [markdown]
# 7.WAP to get a number from the user and using function check if it is positive or negetive

# %%
def check(num):
  if(num>=0):
    print("+ve")
  else:
    print("-ve")

n=int(input("enter the number"))
check(n)
# Out:
# enter the number-69
# -ve

# %% [markdown]
# 8.WAP to get a list of names from user and using a function, capitalize each item and print the new list

# %%
def cap(l):
  nl=[]
  for i in l:
    nl+=[i.upper()]
  print(nl)

limit=int(input("enter the limit"))
lis=[]
for i in range(limit):
  l=input(f"enter the {i+1}th element : ")
  lis+=[l]
print(lis)
cap(lis)
# Out:
# enter the limit5
# enter the 1th element : reg
# enter the 2th element : emme
# enter the 3th element : alex
# enter the 4th element : rene
# enter the 5th element : sean
# ['reg', 'emme', 'alex', 'rene', 'sean']
# ['REG', 'EMME', 'ALEX', 'RENE', 'SEAN']

# %%
def cap(l):
  nl=[]
  for i in l:
    nl+=[i.capitalize()]
  print(nl)

limit=int(input("enter the limit"))
lis=[]
for i in range(limit):
  l=input(f"enter the {i+1}th element : ")
  lis+=[l]
print(lis)
cap(lis)
# Out:
# enter the limit5
# enter the 1th element : reg
# enter the 2th element : alex
# enter the 3th element : sur
# enter the 4th element : ki
# enter the 5th element : emma
# ['reg', 'alex', 'sur', 'ki', 'emma']
# ['Reg', 'Alex', 'Sur', 'Ki', 'Emma']

# %% [markdown]
# 9.WAP to get a list from the user and using function, remove the duplicate and print the new list onto screen.

# %%
def dup(l):
  li=[]
  for i in l:
    if i not in li:
      li+=[i]
  print(li)



limit=int(input("enter the limit"))
lis=[]
for i in range(limit):
  l=input(f"enter the {i+1}th element : ")
  lis+=[l]#lis.append(l)
print(lis)
dup(lis)
# Out:
# enter the limit5
# enter the 1th element : arya
# enter the 2th element : arya
# enter the 3th element : reg emma
# enter the 4th element : elsa
# enter the 5th element : dora
# ['arya', 'arya', 'reg emma', 'elsa', 'dora']
# ['arya', 'reg emma', 'elsa', 'dora']

# %% [markdown]
# 10.WAP to get a number from the user and find the sum of all number

# %%
def sum(n):
  s=0
  for i in range(n+1):
    s+=i
  print(s)

num= int(input("enter the number"))
sum(num)
# Out:
# enter the number1569
# 1231665

# %% [markdown]
# 10.WAP to get a number from the user and find the sum of all numbers from zero till that number

# %%
def sum(n):
  s=0
  for i in range(n+1):
    s+=i
  print(s)

num= int(input("enter the number"))
sum(num)
# Out:
# enter the number10
# 55

# %% [markdown]
# 11.WAP to get a number from the user and find the sum of all the digits in that number

# %%
def sum(n):
  n1=n
  s=0
  while n1>0:
    r=n1%10
    s+=r
    n1=n1//10
  print(f"sum of digits in {n} is {s}")

num=int(input("enter the number"))
sum(num)
# Out:
# enter the number1234
# sum of digits in 1234 is 10

# %%
def sum(l):
  s=0
  for i in l:
    s+=i
  print(f"sum = {s}")

item=int(input("enter the limit"))
lis=[]
for i in range(limit):
  l=int(input(f"enter the {i+1}th element"))
  lis+=[l]
print(lis)
sum(lis)
# Out:
# enter the limit5
# enter the 1th element50
# enter the 2th element1
# enter the 3th element2
# enter the 4th element3
# enter the 5th element80
# [50, 1, 2, 3, 80]
# sum = 136

# %%
x=12
def test():
  print(x)
test()
# Out:
# 12

# %%
def add(x,y):
  print(x+y)
add(12,2)
# Out:
# 14

# %%
def add(x,y):
  return(x+y)
a=add(12,2)
print(a)
print(add(24,5))
# Out:
# 14
# 29

# %%
def dup(l):
  li=[]
  for i in l:
    if i not in li:
      li+=[i]
  print(li)

def get_list():
  limit=int(input("enter the limit"))
  lis=[]
  for i in range(limit):
    l=input(f"enter the {i+1}th element : ")
    lis+=[l]
  return lis
l1=get_list()
print(l1)
dup(l1)
# Out:
# enter the limit5
# enter the 1th element : 25
# enter the 2th element : 30
# enter the 3th element : 60
# enter the 4th element : 89
# enter the 5th element : 25
# ['25', '30', '60', '89', '25']
# ['25', '30', '60', '89']

# %% [markdown]
# 3.WAP to get a list from the user and implement a function to print only the even numbers which are greater than 50
#
# with return

# %%
def even(l):
  li=[]
  for i in l:
    if i%2==0 and i>50:
      li+=[i]
  return(li)

def get_list():
  limit=int(input("enter the limit"))
  lis=[]
  for i in range(limit):
    l=int(input(f"enter the {i+1}th element : "))
    lis+=[l]
  return lis
l1= get_list()
print(l1)
print(even(l1))
# Out:
# enter the limit5
# enter the 1th element : 63
# enter the 2th element : 98
# enter the 3th element : 20
# enter the 4th element : 36
# enter the 5th element : 51
# [63, 98, 20, 36, 51]
# [98]

# %% [markdown]
# 8.WAP to get a list of names from user and using a function, capitalize each item and print the new list
#
# using return

# %%
def cap(l):
  nl=[]
  for i in l:
    nl+=[i.upper()]
  return(nl)

def get_list():
  limit=int(input("enter the limit"))
  lis=[]
  for i in range(limit):
    l=input(f"enter the {i+1}th element : ")
    lis+=[l]
  return lis
l1=get_list()
print(l1)
print(cap(l1))
# Out:
# enter the limit5
# enter the 1th element : surya
# enter the 2th element : regina
# enter the 3th element : arakkal
# enter the 4th element : kiran
# enter the 5th element : mercy
# ['surya', 'regina', 'arakkal', 'kiran', 'mercy']
# ['SURYA', 'REGINA', 'ARAKKAL', 'KIRAN', 'MERCY']

# %%
def cap(l):
  nl=[]
  for i in l:
    nl+=[i.capitalize()]
  return(nl)

def get_list():
  limit=int(input("enter the limit"))
  lis=[]
  for i in range(limit):
    l=input(f"enter the {i+1}th element : ")
    lis+=[l]
  return lis
l1=get_list()
print(l1)
print(cap(l1))
# Out:
# enter the limit5
# enter the 1th element : reg
# enter the 2th element : sur
# enter the 3th element : mer
# enter the 4th element : kir
# enter the 5th element : aug
# ['reg', 'sur', 'mer', 'kir', 'aug']
# ['Reg', 'Sur', 'Mer', 'Kir', 'Aug']

# %% [markdown]
# 9.WAP to get a list from the user and using function, remove the duplicate and print the new list onto screen.
#
# using return

# %%
def dup(l):
  li=[]
  for i in l:
    if i not in li:
      li+=[i]
  return(li)

def get_list():
  limit=int(input("enter the limit"))
  lis=[]
  for i in range(limit):
    l=input(f"enter the {i+1}th element : ")
    lis+=[l]
  return(lis)
l1=get_list()
print(l1)
print(dup(l1))
# Out:
# enter the limit5
# enter the 1th element : 15
# enter the 2th element : 2
# enter the 3th element : 2
# enter the 4th element : 15
# enter the 5th element : 1
# ['15', '2', '2', '15', '1']
# ['15', '2', '1']

# %%
def get_list():
  limit=int(input("enter the limit"))
  lis=[]
  for i in range(limit):
    l=int(input(f"enter the {i+1}th element : "))
    lis.append(l)
  return(lis)

def q(li):
  l=[]
  for j in li:
    if j%2==0 and j > 50:
      l.append(j) #l+=[j]
      #print(j)
  return(l)

l=get_list()
print(l)
a=q(l)
print(a)
# Out:
# enter the limit5
# enter the 1th element : 98
# enter the 2th element : 51
# enter the 3th element : 50
# enter the 4th element : 52
# enter the 5th element : 46
# [98, 51, 50, 52, 46]
# [98, 52]

# %%
def new(elist):
    new=[]
    for item in elist:
      if item>50 and item%2==0:
        new.append(item)
    print(new)

list1=[]    

limit=int(input("enter limit:"))
for i in range(limit):
    item=int(input("enter numbers:"))
    list1.append(item)
new(list1)
# Out:
# enter limit:5
# enter numbers:98
# enter numbers:51
# enter numbers:50
# enter numbers:46
# enter numbers:52
# [98, 52]

# %%
def int_input(msg):
  var=int(input(msg))
  return var
  

num1=int_input("enter a number")
print(num1)
# Out:
# enter a number5
# 5

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
def test(name):
  """test will take a name and greet with hello"""
  print("Hello", name)

help(test)
# Out:
# Help on function test in module __main__:
#
# test(name)
#     test will take a name and greet with hello

# %%
print(test.__doc__)
# Out:
# test will take a name and greet with hello

# %%
print.__class__
# Out:
# builtin_function_or_method

# %%
print.__dir__
# Out:
# <function builtin_function_or_method.__dir__>

# %%
print.__module__
# Out:
# 'builtins'

# %%
help(builtins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-e64d8cb79bbc> in <module>()
# ----> 1 help(builtins)
#
# NameError: name 'builtins' is not defined

# %%
import builtins
help(builtins)
# Out:
# Help on built-in module builtins:
#
# NAME
#     builtins - Built-in functions, exceptions, and other objects.
#
# DESCRIPTION
#     Noteworthy: None is the `nil' object; Ellipsis represents `...' in slices.
#
# CLASSES
#     object
#         BaseException
#             Exception
#                 ArithmeticError
#                     FloatingPointError
#                     OverflowError
#                     ZeroDivisionError
#                 AssertionError
#                 AttributeError
#                 BufferError
#                 EOFError
#                 ImportError
#                     ModuleNotFoundError
#                 LookupError
#                     IndexError
#                     KeyError
#                 MemoryError
#                 NameError
#                     UnboundLocalError
#                 OSError
#                     BlockingIOError
#                     ChildProcessError
#                     ConnectionError
# ...

# %%
print.__doc__
# Out:
# "print(value, ..., sep=' ', end='\\n', file=sys.stdout, flush=False)\n\nPrints the values to a stream, or to sys.stdout by default.\nOptional keyword arguments:\nfile:  a file-like object (stream); defaults to the current sys.stdout.\nsep:   string inserted between values, default a space.\nend:   string appended after the last value, default a newline.\nflush: whether to forcibly flush the stream."

# %%
nums=[12,23,34,45,56]
sum(nums)
print(min(nums))
print(max(nums))
sum((12,445,89))
# Out:
# sum = 170
# 12
# 56
# sum = 546

# %%
nums=[12,23,34,45,56,]
sum(nums)
# Out:
# sum = 170

# %%
string="12,23,34,89,90"
list1=string.split(",")
print(list1)
# Out:
# ['12', '23', '34', '89', '90']

# %%
string="12 23 34 89 90"
list1=string.split(" ")
print(list1)
# Out:
# ['12', '23', '34', '89', '90']

# %%
def convert(l):
  new=[]
  for item in l:
    item=int(item)
    new.append(item)
  return new
nums=['12', '23', '34', '89', '90']
x=convert(nums)
print(x)
print(x[0]+12)
# Out:
# [12, 23, 34, 89, 90]
# 24

# %%
#def test():

var=int(input("enter"))
print(var)
# Out:
# enter5
# 5

# %%
def test():
  return 0

var=int(input("enter"))
print(var)
# Out:
# enter6
# 6

# %%
def test():
  pass

var=int(input("enter"))
print(var)
# Out:
# enter6
# 6

# %% [markdown]
# calculator

# %%
def display():
  n=int(input("enter a number from 1-5\n1. add\n2. sub\n3. mult\n4. div\n5. exp"))
  if n==1:
    r=add()
  elif n==2:
    r=sub()
  elif n==3:
    r=mult()
  elif n==4:
    r=div()
  elif n==5:
    r=exp()
  else:
    print("invalid statement")
  return(r)

def add():
  a=int(input("enter the number1"))
  b=int(input("enter the number2"))
  return(a+b)
def sub():
  a=int(input("enter the number1"))
  b=int(input("enter the number2"))
  return(a-b)
def mult():
  a=int(input("enter the number1"))
  b=int(input("enter the number2"))
  return(a*b)
def div():
  a=int(input("enter the number1"))
  b=int(input("enter the number2"))
  return(a/b)
def exp():
  a=int(input("enter the number1"))
  b=int(input("enter the number2"))
  return(a**b)

print(display())
# Out:
# enter a number from 1-5
# 1. add
# 2. sub
# 3. mult
# 4. div
# 5. exp5
# enter the number12
# enter the number25
# 32

# %%
def burger(q):
  c=(q*50)
  cost(c)
def pizza(q):
  c=(q*100)
  cost(c)
def sandwich(q):
  c=(q*35)
  cost(c)
def frenchfries(q):
  c=(q*20)
  cost(c)

#total=0
def cost(c):
    total=0
    total=total+c
    return(total)

def menu():
  print("\n1.Pizza\n2.Burger\n3.Sandwich\n4.French Fries\n5.exit")
  
menu()
n=0
while n!=5:
  n=int(input("enter your choice :"))
  if n==1:
    q=int(input("enter the quantity"))
    c=pizza(q)
  elif n==2:
    q=int(input("enter the quantity"))
    c=burger(q)
  elif n==3:
    q=int(input("enter the quantity"))
    c=sandwich(q)
  elif n==4:
    q=int(input("enter the quantity"))
    c=frenchfries(q)
  else:
    print("invalid statement")

tc=cost()
# Out:
# 1.Pizza
# 2.Burger
# 3.Sandwich
# 4.French Fries
# 5.exit
# enter your choice :1
# enter the quantity2
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-14-404ad296543b> in <module>()
#      27   if n==1:
#      28     q=int(input("enter the quantity"))
# ---> 29     c=pizza(q)
#      30   elif n==2:
#      31     q=int(input("enter the quantity"))
#
# <ipython-input-14-404ad296543b> in pizza(q)
#       4 def pizza(q):
#       5   c=(q*100)
# ----> 6   cost(c)
#       7 def sandwich(q):
#       8   c=(q*35)
#
# <ipython-input-14-404ad296543b> in cost(c)
#      15 def cost(c):
#      16     #total=0
# ---> 17     total=total+c
#      18     return(total)
#      19
#
# UnboundLocalError: local variable 'total' referenced before assignment

# %% [markdown]
# How to make menu in python

# %%
#total=0
"""
def cost(c):
  total=0
  total +=c
  print(f"total cost upto this is {total}")
"""

def menu(): 
  print("\n") 
  print("[1] Burger")
  print("[2] Pizza")
  print("[0] Exit")

def burger(q):
  print("Burger Function")
  return(50*q)
def pizza(q):
  print("Pizza Function")
  return(100*q)



print("_"*18)
print("|"," "*4,"Menu"," "*4,"|")
print("_"*18)
print("| 1.Burger | 50  |")
print("_"*18)
print("| 2.Pizza  | 100 |")
print("_"*18)

menu()
option=int(input("enter the option"))
total = 0
while option != 0:
  if option == 1:
    print("Option 1 has bee called")
    q=int(input("enter the quantity :"))
    total+=burger(q)
    print(f"total cost upto this is {total}")
  elif option ==2:
    print("Option 2 has bee called")
    q=int(input("enter the quantity :"))
    total+=pizza(q)
    print(f"total cost upto this is {total}")
  else:
    print("Invalid Option")

  menu()
  option=int(input("enter the option"))

print("Thanks for using the program")
# Out:
# __________________
# |      Menu      |
# __________________
# | 1.Burger | 50  |
# __________________
# | 2.Pizza  | 100 |
# __________________
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option1
# Option 1 has bee called
# enter the quantity :2
# Burger Function
# total cost upto this is 100
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option2
# Option 2 has bee called
# enter the quantity :1
# Pizza Function
# total cost upto this is 200
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option0
# Thanks for using the program

# %% [markdown]
# Simple restaurant program

# %%
def menu(): 
  print("\n") 
  print("[1] Burger")
  print("[2] Pizza")
  print("[0] Exit")


print("_"*18)
print("|"," "*4,"Menu"," "*4,"|")
print("_"*18)
print("| 1.Burger | 50  |")
print("_"*18)
print("| 2.Pizza  | 100 |")
print("_"*18)





menu()
option=int(input("enter the option"))

while option != 0:
  if option == 1:
    print("Option 1 has bee called")
  elif option ==2:
    print("Option 2 has bee called")
  else:
    print("Invalid Option")
  menu()
  option=int(input("enter the option"))

print("Thanks for using the program")

# %%
def cost(c):
  global total
  total=total+c
  print(total)


def menu(): 
  print("\n") 
  print("[1] Burger")
  print("[2] Pizza")
  print("[0] Exit")

def burger(q):
  print("Burger Function")
  cost(50*q)
def pizza(q):
  print("Pizza Function")
  cost(100*q)



print("_"*18)
print("|"," "*4,"Menu"," "*4,"|")
print("_"*18)
print("| 1.Burger | 50  |")
print("_"*18)
print("| 2.Pizza  | 100 |")
print("_"*18)

menu()
option=int(input("enter the option"))

while option != 0:
  if option == 1:
    print("Option 1 has bee called")
    q=int(input("enter the quantity :"))
    burger(q)
  elif option ==2:
    print("Option 2 has bee called")
    q=int(input("enter the quantity :"))
    pizza(q)
  else:
    print("Invalid Option")
  menu()
  option=int(input("enter the option"))

print("Thanks for using the program")
# Out:
# __________________
# |      Menu      |
# __________________
# | 1.Burger | 50  |
# __________________
# | 2.Pizza  | 100 |
# __________________
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option1
# Option 1 has bee called
# enter the quantity :2
# Burger Function
# 100
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option3
# Invalid Option
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option2
# Option 2 has bee called
# enter the quantity :5
# Pizza Function
# 600
#
#
# [1] Burger
# [2] Pizza
# [0] Exit
# enter the option0
# Thanks for using the program
